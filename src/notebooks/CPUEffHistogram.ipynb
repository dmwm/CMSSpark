# %%
from pyspark.sql.types import (
    StructType, 
    LongType, 
    StringType, 
    StructField,
    DoubleType
)
from pyspark.sql.functions import (
    regexp_extract,
    date_format,
    from_unixtime,
    substring_index,
    col,
    lit,
    input_file_name,
    concat,
    year,
    month,
    weekofyear,
    lpad,
    countDistinct,
    when,
    min as _min,
    max as _max,
    mean,
    sum as _sum,
)
from pyspark import StorageLevel
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import ipywidgets as widgets

# %% [markdown]
# # Set up the parameters

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2020, 3,1)
#How may bins should we have between 0 and 1 (see this as 1/bin_size)
nbins_0_1 = 1/20

# %%
def _get_candidate_files(start_date, end_date, spark, base="/project/monitoring/archive/condor/raw/metric/"):
    """
    Returns a list of hdfs folders that can contain data for the given dates.
    """
    st_date = start_date - timedelta(days=1)
    ed_date = end_date + timedelta(days=1)
    days = (ed_date - st_date).days
    pre_candidate_files = [
        "{base}/{day}{{,.tmp}}".format(
            base=base, day=(st_date + timedelta(days=i)).strftime("%Y/%m/%d")
        )
        for i in range(0, days)
    ]
    sc = spark.sparkContext
    # The candidate files are the folders to the specific dates,
    # but if we are looking at recent days the compaction procedure could
    # have not run yet so we will considerate also the .tmp folders.
    candidate_files = [
        "/project/monitoring/archive/condor/raw/metric/{}{{,.tmp}}".format(
            (st_date + timedelta(days=i)).strftime("%Y/%m/%d")
        )
        for i in range(0, days)
    ]
    FileSystem = sc._gateway.jvm.org.apache.hadoop.fs.FileSystem
    URI = sc._gateway.jvm.java.net.URI
    Path = sc._gateway.jvm.org.apache.hadoop.fs.Path
    fs = FileSystem.get(URI("hdfs:///"), sc._jsc.hadoopConfiguration())
    candidate_files = [url for url in candidate_files if fs.globStatus(Path(url))]
    return candidate_files

def generate_histogram(pd_data, bin_field, max_value=4, stacked=True):
    """
    Generate a plot based on the data provided. This method expects
    a pandas dataframe (pd_data) with a field defining the bins (bin_field)
    and the Type and count fields. 
    It will generate an stacked bar plot 
    """
    cms_types = pd_data.Type.unique()
    trimed = pd_data[np.logical_or(pd_data[bin_field].isnull(), pd_data[bin_field] < max_value) ].copy()
    trimed[bin_field] =  trimed[bin_field].astype(float).round(1).astype(str).str.zfill(int(np.log10(max_value))+3)
    grouped=pd_data[pd_data[bin_field]>max_value].groupby("Type").sum().reset_index()
    grouped[bin_field] = f"{max_value}+"
    full = pd.concat([trimed, grouped], sort=True)
    pivoted = full.pivot(index=bin_field, columns="Type", values="count")
    colors = sns.color_palette("hls", len(cms_types))
    sns.set(style="white")
    fig, ax = plt.subplots(figsize=(40, 7))
    pivoted.plot.bar(stacked=stacked, color=colors, ax=ax)
    return fig

# %%
schema = StructType([
    StructField('data', StructType([
        StructField("GlobalJobId", StringType(), nullable=False),
        StructField("Workflow", StringType(), nullable=False),
        StructField("RecordTime", LongType(), nullable=False),
        StructField("JobFailed", LongType(), nullable=False),
        StructField("Status", StringType(), nullable=True),
        StructField("Site", StringType(), nullable=True),
        StructField("Type", StringType(), nullable=True),
        StructField("WallClockHr", DoubleType(), nullable=False),
        StructField("CpuTimeHr", DoubleType(), nullable=True),
        StructField("RequestCpus", DoubleType(), nullable=True),
        StructField("CpuEff", DoubleType(), nullable=True),
    ])),
])

# %%
spark.catalog.clearCache()
folder = "/project/monitoring/archive/condor/raw/metric/"
raw_df = (spark.read.option("basePath",folder).json(_get_candidate_files(start_date, end_date, spark, base=folder),schema=schema)
          .select("data.*")
          .filter(f"""Status='Completed'
          AND JobFailed=0
          AND RecordTime >= {start_date.timestamp()*1000}
          AND RecordTime < {end_date.timestamp()*1000}
          """)
          .drop_duplicates(['GlobalJobId'])
        )

# %%
#raw_df.head()

# %%
raw_df = (raw_df.withColumn("RequestCpus",
                            when(col("RequestCpus").isNotNull(),
                                 col("RequestCpus"))
                            .otherwise(lit(1)))
          .withColumn("CoreTime", col("WallClockHr")*col("RequestCpus"))
         )

# %% [markdown]
# # Plots

# %%
grouped_wf = (raw_df.groupby("Workflow", "Type")
                    .agg(mean("CpuEff").alias("mean_cpueff"), 
                         (100*_sum("CpuTimeHr")/_sum("CoreTime")).alias("wf_cpueff"),
                         _sum("RequestCpus").alias("wf_cpus"),
                         _sum("CpuTimeHr").alias("wf_cputimehr"),
                         _sum("WallClockHr").alias("wf_wallclockhr")
                        )
                    .cache()
             )

# %%
filtered = grouped_wf.selectExpr("Workflow", "Type", "mean_cpueff", "wf_cpueff", f"floor(mean_cpueff * {nbins_0_1})/{nbins_0_1} as binsEff1", f"floor(wf_cpueff * {nbins_0_1})/{nbins_0_1} as binsEff2")

# %%
pd_Eff1 = filtered.groupby("Type", "binsEff1").count().toPandas()
pd_Eff2 = filtered.groupby("Type", "binsEff2").count().toPandas()

# %%
histo_eff1 = generate_histogram(pd_Eff1, "binsEff1", max_value=120)
histo_eff1_ns = generate_histogram(pd_Eff1, "binsEff1", max_value=120, stacked=False)
histo_eff1.savefig(f"binsEff1_{start_date.strftime('%Y%m%d')}-{end_date.strftime('%Y%m%d')}.png")
histo_eff1_ns.savefig(f"binsEff1-ns_{start_date.strftime('%Y%m%d')}-{end_date.strftime('%Y%m%d')}.png")

# %%
histo_eff2 = generate_histogram(pd_Eff2, "binsEff2", max_value=120)
histo_eff2_ns = generate_histogram(pd_Eff2, "binsEff2", max_value=120, stacked=False)

# %% [markdown]
# # List of workflows
# Run the widgets cell once, then you can select the values and run the cells below the widgets to get results with the new parameters.

# %%
cms_types = grouped_wf.select('Type').distinct().toPandas().Type.tolist()
range_slider = widgets.FloatRangeSlider(
    value=[0, 0.5],
    min=0,
    max=120,
    step=1/nbins_0_1,
    description='MemoryEff range:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.2f',
)
type_selector = widgets.SelectMultiple(
    options=cms_types,
    value=(cms_types[0], ) if cms_types else (),
    description='Type:',
    disabled=False,
)
display(range_slider)
display(type_selector)
# Out:
# FloatRangeSlider(value=(0.0, 0.5), continuous_update=False, description='MemoryEff range:', max=120.0, step=20…
# SelectMultiple(description='Type:', index=(0,), options=('production', 'analysis', 'test', 'tier0'), value=('p…

# %%
select_expr = f"""wf_cpueff BETWEEN {range_slider.value[0]} AND {range_slider.value[1]}
 AND Type in ({",".join([f"'{x}'" for x in type_selector.value])})
"""

# %%
print(select_expr)
selected_df = (
    grouped_wf.where(select_expr)
)
# Out:
# wf_cpueff BETWEEN 0.0 AND 0.5
#  AND Type in ('production')

# %%
selected_pd = selected_df.toPandas()

# %%
selected_pd
# Out:
#                                              Workflow        Type  \
# 0   cmsunified_ACDC1_task_B2G-RunIISummer15wmLHEGS...  production
# 1   cmsunified_ACDC0_task_B2G-RunIIFall17wmLHEGS-0...  production
# 2                    EXO-RunIISummer16NanoAODv6-06676  production
# 3   sagarwal_r-0-Run2018B-v1-MET-12Nov2019_UL2018_...  production
# 4   cmsunified_ACDC1_Run2017C-09Aug2019_UL2017-v1-...  production
# 5   pdmvserv_task_B2G-RunIISummer15wmLHEGS-02711__...  production
# 6                    BPH-RunIIAutumn18NanoAODv6-00115  production
# 7                    HIG-RunIISummer16NanoAODv5-03636  production
# 8   cmsunified_ACDC1_task_B2G-RunIISummer15wmLHEGS...  production
# 9                    HIG-RunIIAutumn18NanoAODv5-02178  production
# 10                   BPH-RunIIAutumn18NanoAODv6-00118  production
# 11  sagarwal_r-1-Run2018B-v1-MET-12Nov2019_UL2018_...  production
# 12                 EGM-RunIISummer19UL17NanoAOD-00007  production
# 13                   HIG-RunIIAutumn18NanoAODv6-00718  production
# 14  sagarwal_r-3-Run2018B-v1-MET-12Nov2019_UL2018_...  production
# 15                     FSQ-RunIIFall17NanoAODv6-00005  production
# 16                   HIG-RunIIAutumn18NanoAODv6-02172  production
# 17  cmsunified_ACDC2_task_B2G-RunIISummer15wmLHEGS...  production
# 18                     EXO-RunIIFall17NanoAODv6-03168  production
# 19  pgunnell_Run2016F-v1-JetHT-ForValUL2016_HIPM_E...  production
# 20                     SMP-RunIIFall17NanoAODv6-00182  production
# 21  cmsunified_ACDC0_task_B2G-RunIIFall17wmLHEGS-0...  production
# 22                     BTV-RunIISummer19UL18GEN-00022  production
# 23                   HIG-RunIISummer16NanoAODv5-03652  production
# 24  cmsunified_ACDC0_Run2017B-v1-MET-09Aug2019_UL2...  production
# 25  cmsunified_ACDC0_task_B2G-RunIIFall17wmLHEGS-0...  production
# 26  cmsunified_ACDC0_task_B2G-RunIIFall17wmLHEGS-0...  production
# 27                 EGM-RunIISummer19UL17NanoAOD-00008  production
# 28  pdmvserv_task_B2G-RunIIFall17NanoAODv5-02211__...  production
# 29                  HIG-RunIISummer16DR80Premix-05237  production
# ..                                                ...         ...
# 37  pdmvserv_task_B2G-RunIISummer15wmLHEGS-02696__...  production
# 38                     BTV-RunIISummer19UL18GEN-00025  production
# 39  cmsunified_ACDC0_task_B2G-RunIIFall17NanoAODv6...  production
# 40                   BPH-RunIIAutumn18NanoAODv6-00168  production
# 41                     BTV-RunIISummer19UL18GEN-00029  production
# 42                   TOP-RunIISummer16NanoAODv6-00294  production
# 43  cmsunified_ACDC0_task_B2G-RunIIFall17wmLHEGS-0...  production
# 44  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 45  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 46  cmsunified_ACDC2_task_B2G-RunIISummer15wmLHEGS...  production
# 47  cmsunified_ACDC0_task_B2G-RunIIFall17NanoAODv6...  production
# 48  pdmvserv_task_B2G-RunIISummer16NanoAODv6-02248...  production
# 49  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 50                     BTV-RunIISummer19UL18GEN-00026  production
# 51  cmsunified_ACDC0_Run2016B-v2-MET-ForValUL2016_...  production
# 52  cmsunified_ACDC0_Run2017C-v1-JetHT-09Aug2019_U...  production
# 53  cmsunified_ACDC0_Run2018B-v1-MET-12Nov2019_UL2...  production
# 54                   HIG-RunIISummer16NanoAODv5-03644  production
# 55  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 56  cmsunified_ACDC1_task_B2G-RunIISummer16NanoAOD...  production
# 57  cmsunified_ACDC0_Run2018B-v1-MET-12Nov2019_UL2...  production
# 58                   PPD-RunIISummer17PrePremix-00018  production
# 59  sagarwal_r-2-Run2018B-v1-MET-12Nov2019_UL2018_...  production
# 60                   HIG-RunIISummer16NanoAODv5-03645  production
# 61                     HIG-RunIIFall17NanoAODv5-05188  production
# 62  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 63  pdmvserv_task_B2G-RunIIAutumn18NanoAODv5-02809...  production
# 64                HIG-RunIISummer19UL17wmLHEGEN-00202  production
# 65  cmsunified_ACDC0_task_B2G-RunIISummer15wmLHEGS...  production
# 66                   HIG-RunIISummer16NanoAODv5-03642  production
#
#     mean_cpueff  wf_cpueff  wf_cpus  wf_cputimehr  wf_wallclockhr
# 0      0.000000   0.000000      1.0      0.000000        0.006944
# 1      0.000000   0.000000      1.0      0.000000        0.010833
# 2      0.000000   0.000000      6.0      0.000000        0.170278
# 3      0.000000   0.000000      2.0      0.000000        0.019722
# 4      0.000000   0.000000      1.0      0.000000        0.009722
# 5      0.000000   0.000000      2.0      0.000000        0.009167
# 6      0.168919   0.178253      2.0      0.000278        0.155833
# 7      0.000000   0.000000      9.0      0.000000        0.075556
# 8      0.000000   0.000000      1.0      0.000000        0.008889
# 9      0.000000   0.000000      3.0      0.000000        0.019722
# 10     0.000000   0.000000      2.0      0.000000        0.043611
# 11     0.000000   0.000000      1.0      0.000000        0.008333
# 12     0.000000   0.000000      1.0      0.000000        0.005556
# 13     0.000000   0.000000      2.0      0.000000        0.010556
# 14     0.000000   0.000000      1.0      0.000000        0.009444
# 15     0.000000   0.000000      3.0      0.000000        0.063611
# 16     0.000000   0.000000      1.0      0.000000        0.008056
# 17     0.000000   0.000000      1.0      0.000000        0.011944
# 18     0.000000   0.000000      8.0      0.000000        0.101111
# 19     0.177601   0.234314      4.0      0.002500        1.066944
# 20     0.000000   0.000000      4.0      0.000000        0.275833
# 21     0.000000   0.000000      1.0      0.000000        0.008889
# 22     0.010900   0.031192      3.0      0.000278        0.890556
# 23     0.000000   0.000000      6.0      0.000000        0.078056
# 24     0.265957   0.261780      2.0      0.000278        0.106111
# 25     0.000000   0.000000      1.0      0.000000        0.008889
# 26     0.000000   0.000000      1.0      0.000000        0.014444
# 27     0.000000   0.000000      3.0      0.000000        0.027222
# 28     0.000000   0.000000      1.0      0.000000        0.002778
# 29     0.618067   0.469298    502.0      0.283056       60.314722
# ..          ...        ...      ...           ...             ...
# 37     1.972308   0.215629     72.0      0.433889       25.731944
# 38     0.008221   0.031397      4.0      0.000278        0.884722
# 39     0.000000   0.000000      1.0      0.000000        0.005278
# 40     0.414365   0.437318      2.0      0.000833        0.190556
# 41     0.000000   0.000000      4.0      0.000000        0.039167
# 42     0.000000   0.000000      1.0      0.000000        0.006389
# 43     1.335520   0.209059      2.0      0.000833        0.398611
# 44     0.000000   0.000000      1.0      0.000000        0.007778
# 45     0.000000   0.000000      1.0      0.000000        0.006944
# 46     0.000000   0.000000      1.0      0.000000        0.007778
# 47     0.000000   0.000000      1.0      0.000000        0.007778
# 48     0.000000   0.000000      1.0      0.000000        0.006944
# 49     0.000000   0.000000      1.0      0.000000        0.005000
# 50     0.011542   0.032744      3.0      0.000278        0.848333
# 51     0.000000   0.000000      1.0      0.000000        0.004722
# 52     0.000000   0.000000      2.0      0.000000        0.026944
# 53     0.000000   0.000000      2.0      0.000000        0.017500
# 54     0.000000   0.000000      6.0      0.000000        0.079722
# 55     0.000000   0.000000      1.0      0.000000        0.003889
# 56     0.000000   0.000000      1.0      0.000000        0.046389
# 57     0.000000   0.000000      2.0      0.000000        0.018889
# 58     0.115333   0.165682    207.0      0.025000       15.089167
# 59     0.000000   0.000000      1.0      0.000000        0.008889
# 60     0.000000   0.000000      3.0      0.000000        0.251944
# 61     0.000000   0.000000      1.0      0.000000        0.005556
# 62     0.000000   0.000000      1.0      0.000000        0.006111
# 63     0.000000   0.000000      1.0      0.000000        0.006389
# 64     0.000000   0.000000      3.0      0.000000        0.044167
# 65     0.000000   0.000000      1.0      0.000000        0.028889
# 66     0.000000   0.000000      9.0      0.000000        0.179167
#
# [67 rows x 7 columns]

# %%
selected_pd.to_csv(f"workflows_cpueff{range_slider.value[0]}-{range_slider.value[1]}_{'-'.join(type_selector.value)}.csv.gz")
